# %%
import pandas as pd

df = pd.read_csv(
    "https://data.cityofnewyork.us/api/views/w7w3-xahh/rows.csv?accessType=DOWNLOAD",
    nrows=5,
)
print(df.columns)
# Out:
# Index(['License Number', 'Business Name', 'DBA/Trade Name',
#        'Business Unique ID', 'Business Category', 'License Type',
#        'License Status', 'Initial Issuance Date', 'Expiration Date', 'Details',
#        'Contact Phone', 'Address Type', 'Building Number', 'Street1',
#        'Street2', 'Street3', 'Unit Type', 'Apt/Suite', 'City', 'State',
#        'ZIP Code', 'Borough', 'Community Board', 'Council District', 'BIN',
#        'BBL', 'NTA', 'Census Block (2010)', 'Census Tract (2010)', 'Latitude',
#        'Longitude'],
#       dtype='object')
